# %% [markdown]
# # Phase 2 - Model Preprocessing

# %%
 # ============================================
# 1. IMPORT LIBRARIES
# ============================================

import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import train_test_split


# ============================================
# 2. LOAD CLEANED DATASET
# ============================================

df = pd.read_csv("cleaned_wifi_data.csv")

print("\n--- DATA LOADED ---\n")
print(df.head())


# ============================================
# 3. VERIFY DATA CLEANNESS
# ============================================

print("\n--- MISSING VALUES ---\n")
print(df.isnull().sum())

print("\n--- DUPLICATES ---\n")
print(df.duplicated().sum())


# ============================================
# 4. REMOVE DUPLICATES (IF ANY)
# ============================================

df = df.drop_duplicates()

print("\n--- AFTER REMOVING DUPLICATES ---\n")
print(df.shape)


# ============================================
# 5. ENCODING (TARGET VARIABLE)
# ============================================

print("\n--- BEFORE ENCODING ---\n")
print(df["congestion_level"].unique())

df["congestion_level"] = df["congestion_level"].map({
    "Low": 0,
    "Medium": 1,
    "High": 2
})

print("\n--- AFTER ENCODING ---\n")
print(df["congestion_level"].unique())


# ============================================
# 6. FEATURE & TARGET SPLIT
# ============================================

X = df.drop("congestion_level", axis=1)
y = df["congestion_level"]

print("\n--- FEATURES SHAPE ---\n", X.shape)
print("\n--- TARGET SHAPE ---\n", y.shape)


# ============================================
# 7. MINMAX SCALING
# ============================================

minmax = MinMaxScaler()

X_minmax = minmax.fit_transform(X)

X_minmax = pd.DataFrame(X_minmax, columns=X.columns)

print("\n--- MINMAX SCALED DATA ---\n")
print(X_minmax.head())


# ============================================
# 8. STANDARD SCALING
# ============================================

standard = StandardScaler()

X_standard = standard.fit_transform(X)

X_standard = pd.DataFrame(X_standard, columns=X.columns)

print("\n--- STANDARD SCALED DATA ---\n")
print(X_standard.head())


# ============================================
# 9. TRAIN-TEST SPLIT
# ============================================

X_train, X_test, y_train, y_test = train_test_split(
    X_minmax, y, test_size=0.2, random_state=42
)

print("\n--- TRAIN TEST SPLIT ---\n")
print("X_train:", X_train.shape)
print("X_test:", X_test.shape)
print("y_train:", y_train.shape)
print("y_test:", y_test.shape)


# ============================================
# 10. FINAL CHECK
# ============================================

print("\n--- FINAL DATA READY FOR MODEL TRAINING ---\n")
print(X_train.head())
# Out:
# --- DATA LOADED ---
#
#    num_devices  latency  packet_loss  signal_strength  bandwidth  channel  \
# 0           39      105          5.9              -42          9        9
# 1           29      189          0.6              -55         37        2
# 2           15      122          5.6              -79         69        4
# 3           43       71          3.5              -50         22        6
# 4            8      195          4.4              -72         53        2
#
#    noise_level  throughput  upload_speed  download_speed  jitter  distance  \
# 0          -93          61            23              63      34        25
# 1          -78          35            49              88      36        21
# 2          -75          10             9              10       2        15
# 3          -89          44            35              23      15         1
# 4          -75          16            20              61      34        12
#
#    obstacles  router_load congestion_level
# 0          1           11           Medium
# 1          5           20           Medium
# 2          4           59           Medium
# 3          0           40              Low
# 4          0           65           Medium
#
# --- MISSING VALUES ---
#
# num_devices         0
# latency             0
# packet_loss         0
# signal_strength     0
# bandwidth           0
# channel             0
# noise_level         0
# throughput          0
# upload_speed        0
# download_speed      0
# jitter              0
# distance            0
# obstacles           0
# router_load         0
# congestion_level    0
# dtype: int64
#
# --- DUPLICATES ---
#
# 0
#
# --- AFTER REMOVING DUPLICATES ---
#
# (200, 15)
#
# --- BEFORE ENCODING ---
#
# ['Medium' 'Low' 'High']
#
# --- AFTER ENCODING ---
#
# [1 0 2]
#
# --- FEATURES SHAPE ---
#  (200, 14)
#
# --- TARGET SHAPE ---
#  (200,)
#
# --- MINMAX SCALED DATA ---
#
#    num_devices   latency  packet_loss  signal_strength  bandwidth  channel  \
# 0     0.791667  0.502674     0.595960         0.813559   0.042553      0.8
# 1     0.583333  0.951872     0.060606         0.593220   0.340426      0.1
# 2     0.291667  0.593583     0.565657         0.186441   0.680851      0.3
# 3     0.875000  0.320856     0.353535         0.677966   0.180851      0.5
# 4     0.145833  0.983957     0.444444         0.305085   0.510638      0.1
#
#    noise_level  throughput  upload_speed  download_speed    jitter  distance  \
# 0     0.179487    0.666667      0.458333        0.617021  0.687500  0.857143
# 1     0.564103    0.357143      1.000000        0.882979  0.729167  0.714286
# 2     0.641026    0.059524      0.166667        0.053191  0.020833  0.500000
# 3     0.282051    0.464286      0.708333        0.191489  0.291667  0.000000
# 4     0.641026    0.130952      0.395833        0.595745  0.687500  0.392857
#
#    obstacles  router_load
# 0        0.2     0.011236
# 1        1.0     0.112360
# 2        0.8     0.550562
# 3        0.0     0.337079
# 4        0.0     0.617978
#
# --- STANDARD SCALED DATA ---
#
#    num_devices   latency  packet_loss  signal_strength  bandwidth   channel  \
# 0     1.000268 -0.138191     0.293670         1.022711  -1.519492  1.024336
# 1     0.286046  1.419935    -1.483101         0.284086  -0.542439 -1.262858
# 2    -0.713865  0.177144     0.193098        -1.079528   0.574193 -0.609374
# 3     1.285957 -0.768861    -0.510906         0.568173  -1.065860  0.044110
# 4    -1.213820  1.531230    -0.209190        -0.681807   0.015877 -1.262858
#
#    noise_level  throughput  upload_speed  download_speed    jitter  distance  \
# 0    -1.152583    0.670220     -0.184475        0.405998  0.609144  1.212512
# 1     0.165157   -0.442889      1.749535        1.303826  0.743687  0.726778
# 2     0.428705   -1.513186     -1.225865       -1.497398 -1.543546 -0.001821
# 3    -0.801186   -0.057582      0.708145       -1.030527 -0.669016 -1.701888
# 4     0.428705   -1.256315     -0.407630        0.334172  0.609144 -0.366121
#
#    obstacles  router_load
# 0  -0.960980    -1.511143
# 1   1.361630    -1.174460
# 2   0.780978     0.284497
# 3  -1.541632    -0.426277
# 4  -1.541632     0.508952
#
# --- TRAIN TEST SPLIT ---
#
# X_train: (160, 14)
# X_test: (40, 14)
# y_train: (160,)
# y_test: (40,)
#
# --- FINAL DATA READY FOR MODEL TRAINING ---
#
#      num_devices   latency  packet_loss  signal_strength  bandwidth  channel  \
# 79      0.270833  0.737968     0.212121         0.593220   0.531915      0.7
# 197     0.479167  0.807487     0.121212         0.491525   0.712766      0.7
# 38      0.750000  0.513369     0.525253         0.067797   0.531915      0.4
# 24      0.666667  0.684492     0.616162         0.593220   0.042553      0.5
# 122     0.458333  0.764706     0.797980         0.338983   0.521277      0.3
#
#      noise_level  throughput  upload_speed  download_speed    jitter  \
# 79      0.717949    0.845238      0.875000        0.074468  0.958333
# 197     0.538462    0.047619      0.958333        0.510638  0.000000
# 38      0.230769    0.226190      0.083333        0.457447  0.395833
# 24      0.256410    0.119048      0.833333        0.478723  0.854167
# 122     0.794872    0.285714      0.104167        0.329787  0.395833
#
#      distance  obstacles  router_load
# 79   0.035714        0.0     0.449438
# 197  0.714286        0.2     0.831461
# 38   1.000000        1.0     0.685393
# 24   0.464286        0.0     0.415730
# 122  0.000000        0.2     0.640449
